# %% [markdown]
# # Text2SQL - Query Decomposition
#
# 복잡한 질문을 **서브 질문으로 분해**하여 Text2SQL 정확도를 높이는 기법을 학습합니다.
#
# 1. 복잡한 자연어 질문이 단일 SQL로 처리되기 어려운 이유 이해
# 2. **Query Decomposition** 기법으로 서브 질문 분해 및 개별 처리
# 3. 분해 전략(compare, aggregate, sequential) 구분 및 적용
# 4. LangGraph 기반 **분해-실행-종합** 파이프라인 구축
# 5. Few-Shot(005)과 결합한 통합 파이프라인 구현
#
# > 참고자료: [DIN-SQL](https://arxiv.org/abs/2304.11015) - Decomposed In-Context Learning for Text2SQL
#
# ---

# %% [markdown]
# ## 사전 준비
#
# **필수 파일:**
# - `etf_database.db`: ETF 정보 데이터베이스 (001에서 생성)
#
# **필수 라이브러리:**
# - `langchain`, `langchain-openai`, `langchain-community`
# - `langgraph`
#
# **환경변수:**
# - `OPENAI_API_KEY`: OpenAI API 키
#
# ---

# %% [markdown]
# ## 환경 설정 및 준비

# %% [markdown]
# `(1) Env 환경변수`

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# `(2) 기본 라이브러리`

# %%
import os
from pprint import pprint
import json

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# `(3) SQLite DB`

# %%
from langchain_community.utilities import SQLDatabase
import ast

db = SQLDatabase.from_uri("sqlite:///etf_database.db", ignore_tables=["ETFsInfo"])
print(db.dialect)
print(db.get_usable_table_names())
print(db.get_table_info()[:500])
# Out:
# sqlite
# ['ETFs']
#
# CREATE TABLE "ETFs" (
# 	"종목코드" TEXT,
# 	"종목명" TEXT,
# 	"상장일" TEXT,
# 	"분류체계" TEXT,
# 	"운용사" TEXT,
# 	"수익률_최근1년" REAL,
# 	"기초지수" TEXT,
# 	"추적오차" REAL,
# 	"순자산총액" REAL,
# 	"괴리율" REAL,
# 	"변동성" TEXT,
# 	"복제방법" TEXT,
# 	"총보수" REAL,
# 	"과세유형" TEXT,
# 	PRIMARY KEY ("종목코드")
# )
#
# /*
# 3 rows from ETFs table:
# 종목코드	종목명	상장일	분류체계	운용사	수익률_최근1년	기초지수	추적오차	순자산총액	괴리율	변동성	복제방법	총보수	과세유형
# 466400	1Q 25-08 회사채(A+이상)액티브	2023/09/19	채권-회사채-단기	하나자산운용	4.52	KIS 2025-08만기형 크레딧 A+이상 지수(총수익)	0.11	111916276404.0	0.03	매우낮음	실물(액티브)	0.1	배당소득세(보유기간과

# %% [markdown]
# `(4) 기본 컴포넌트 준비`

# %%
from typing import TypedDict, Annotated, List
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.tools import QuerySQLDatabaseTool
from langchain_core.vectorstores import InMemoryVectorStore
from langgraph.graph import START, END, StateGraph
from IPython.display import Image, display

# LLM 모델 생성
llm = ChatOpenAI(model="gpt-4.1-mini")

# 임베딩 모델
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %% [markdown]
# ---
#
# ## 1. 기본 SQL Chain 준비
#
# 004에서 구현한 Entity Matching 기반 Chain을 재사용합니다.
# 이 Chain은 고유명사 벡터 스토어를 활용하여 운용사/종목명을 정확히 매칭합니다.

# %%
import re

# 고유명사 추출
def query_as_list(db, query):
    res = db.run(query)
    res = [el for sub in ast.literal_eval(res) for el in sub if el]
    res = [re.sub(r"\b\d+\b", "", string).strip() for string in res]
    return list(set(res))

etfs = query_as_list(db, "SELECT DISTINCT 종목명 FROM ETFs")
fund_managers = query_as_list(db, "SELECT DISTINCT 운용사 FROM ETFs")
print(f"ETF 종목 수: {len(etfs)}, 운용사 수: {len(fund_managers)}")

# 엔티티 벡터 스토어
etf_store = InMemoryVectorStore(embeddings)
manager_store = InMemoryVectorStore(embeddings)
_ = etf_store.add_texts(etfs)
_ = manager_store.add_texts(fund_managers)
etf_retriever = etf_store.as_retriever(search_kwargs={"k": 20})
manager_retriever = manager_store.as_retriever(search_kwargs={"k": 10})
# Out:
# ETF 종목 수: 925, 운용사 수: 26

# %%
from langchain_core.tools import tool

@tool("search_proper_nouns")
def entity_retriever_tool(query: str) -> str:
    """
    Use to look up values to filter on. Input is an approximate spelling 
    of the proper noun, output is valid proper nouns. Use the noun most 
    similar to the search.
    """
    etf_docs = etf_retriever.invoke(query)
    manager_docs = manager_retriever.invoke(query)

    result = "<자산운용사>\n"+"\n".join([doc.page_content for doc in manager_docs]) + "\n</자산운용사>"
    result += "\n---\n<펀드명>\n"+"\n".join([doc.page_content for doc in etf_docs]) + "\n</펀드명>"
    return result

# 기본 State
class State(TypedDict):
    question: str
    query: str
    result: str
    answer: str

class QueryOutput(TypedDict):
    """Generated SQL query."""
    query: Annotated[str, ..., "Syntactically valid SQL query."]
    verification: Annotated[str,..., "Verify the generated SQL query and leave a brief explaination."]
# SQL 생성 프롬프트
query_prompt_template = ChatPromptTemplate.from_template("""
Given an input question, create a syntactically correct {dialect} query to run to help find the answer.
Unless the user specifies a specific number, always limit to at most {top_k} results.
Order by relevant columns. Only ask for relevant columns.
Pay attention to column names in the schema. Be careful not to query non-existent columns.

Only use the following tables:
{table_info}

Entity names to consider:
{entity_info}

Question: {input}
""")

def write_query(state: State):
    """SQL 쿼리 생성 (엔티티 매칭)"""
    prompt = query_prompt_template.invoke({
        "dialect": db.dialect,
        "top_k": 10,
        "table_info": db.get_table_info(),
        "entity_info": entity_retriever_tool.invoke(state["question"]),
        "input": state["question"],
    })
    structured_llm = llm.with_structured_output(QueryOutput)
    result = structured_llm.invoke(prompt)
    return {"query": result["query"]}

def execute_query(state: State):
    """SQL 쿼리 실행"""
    try:
        tool = QuerySQLDatabaseTool(db=db)
        return {"result": tool.invoke(state["query"])}
    except Exception as e:
        return {"result": f"쿼리 실행 중 오류 발생: {str(e)}"}

def generate_answer(state: State):
    """답변 생성"""
    prompt = (
        "Given the following user question, corresponding SQL query, "
        "and SQL result, answer the user question in Korean language.\n\n"
        f'Question: {state["question"]}\n'
        f'SQL Query: {state["query"]}\n'
        f'SQL Result: {state["result"]}'
    )
    response = llm.invoke(prompt)
    return {"answer": response.content}

# 기본 그래프
basic_graph = StateGraph(State)
basic_graph.add_node("write_query", write_query)
basic_graph.add_node("execute_query", execute_query)
basic_graph.add_node("generate_answer", generate_answer)
basic_graph.add_edge(START, "write_query")
basic_graph.add_edge("write_query", "execute_query")
basic_graph.add_edge("execute_query", "generate_answer")
basic_chain = basic_graph.compile()

display(Image(basic_chain.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### 1.1 Few-Shot 예시 벡터 스토어 준비
#
# 005에서 구축한 동적 Few-Shot 예시 시스템을 재사용합니다.
# Decomposition에서 각 서브 질문을 처리할 때 Few-Shot 예시를 활용하면 SQL 생성 정확도가 높아집니다.

# %%
from langchain_core.documents import Document

# Few-Shot 예시 데이터셋
examples = [
    {"question": "ETF 총 개수는?", "sql": "SELECT COUNT(*) FROM ETFs", "category": "count"},
    {"question": "총보수가 0.1% 이하인 ETF는?", "sql": "SELECT 종목명, 총보수 FROM ETFs WHERE 총보수 <= 0.1 ORDER BY 총보수 ASC LIMIT 10", "category": "filter"},
    {"question": "순자산총액이 가장 큰 ETF는?", "sql": "SELECT 종목명, 순자산총액 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 1", "category": "sort"},
    {"question": "운용사별 ETF 개수는?", "sql": "SELECT 운용사, COUNT(*) as cnt FROM ETFs GROUP BY 운용사 ORDER BY cnt DESC LIMIT 10", "category": "aggregation"},
    {"question": "평균 수익률이 가장 높은 분류체계는?", "sql": "SELECT 분류체계, AVG(수익률_최근1년) as avg_ret FROM ETFs GROUP BY 분류체계 ORDER BY avg_ret DESC LIMIT 5", "category": "aggregation"},
    {"question": "운용사별 평균 총보수를 비교해주세요", "sql": "SELECT 운용사, AVG(총보수) as avg_fee FROM ETFs GROUP BY 운용사 ORDER BY avg_fee ASC LIMIT 10", "category": "aggregation"},
    {"question": "KB자산운용의 ETF 중 수익률 상위 5개는?", "sql": "SELECT 종목명, 수익률_최근1년 FROM ETFs WHERE 운용사 = 'KB자산운용' ORDER BY 수익률_최근1년 DESC LIMIT 5", "category": "filter_sort"},
    {"question": "삼성자산운용의 ETF 수는?", "sql": "SELECT COUNT(*) FROM ETFs WHERE 운용사 = '삼성자산운용'", "category": "filter_count"},
    {"question": "순자산 1000억 이상이고 총보수 0.3% 이하인 ETF는?", "sql": "SELECT 종목명, 순자산총액, 총보수 FROM ETFs WHERE 순자산총액 >= 100000000000 AND 총보수 <= 0.3 ORDER BY 순자산총액 DESC LIMIT 10", "category": "complex"},
    {"question": "수익률이 양수이고 변동성이 낮은 ETF를 추천해주세요", "sql": "SELECT 종목명, 수익률_최근1년, 변동성 FROM ETFs WHERE 수익률_최근1년 > 0 AND 변동성 = '매우낮음' ORDER BY 수익률_최근1년 DESC LIMIT 10", "category": "complex"},
    {"question": "분류체계별 ETF 개수를 비교해주세요", "sql": "SELECT 분류체계, COUNT(*) as cnt FROM ETFs GROUP BY 분류체계 ORDER BY cnt DESC", "category": "comparison"},
    {"question": "복제방법별 평균 추적오차는?", "sql": "SELECT 복제방법, AVG(추적오차) as avg_error FROM ETFs GROUP BY 복제방법 ORDER BY avg_error ASC", "category": "comparison"},
    {"question": "수익률 상위 10% ETF의 평균 총보수는?", "sql": "SELECT AVG(총보수) as avg_fee FROM (SELECT 총보수 FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT (SELECT COUNT(*) / 10 FROM ETFs))", "category": "advanced"},
]

# 벡터 스토어에 저장
example_docs = [
    Document(page_content=ex["question"], metadata={"sql": ex["sql"], "category": ex["category"]})
    for ex in examples
]
example_store = InMemoryVectorStore(embeddings)
_ = example_store.add_documents(example_docs)
example_retriever = example_store.as_retriever(search_kwargs={"k": 3})

print(f"Few-Shot 예시 벡터 스토어 구축 완료: {len(example_docs)}개")
# Out:
# Few-Shot 예시 벡터 스토어 구축 완료: 13개

# %%
def format_examples(docs):
    """검색된 예시를 프롬프트 형식으로 변환"""
    formatted = []
    for doc in docs:
        formatted.append(
            f"Question: {doc.page_content}\n"
            f"SQL: {doc.metadata['sql']}"
        )
    return "\n\n".join(formatted)

# Few-Shot 프롬프트 템플릿
fewshot_prompt_template = ChatPromptTemplate.from_template("""
Given an input question, create a syntactically correct {dialect} query to run to help find the answer.
Unless the user specifies a specific number, always limit to at most {top_k} results.
Order by relevant columns. Only ask for relevant columns.
Pay attention to column names in the schema.

Only use the following tables:
{table_info}

Entity names to consider:
{entity_info}

Here are some similar examples for reference:

{examples}

Now generate the SQL for this question:
Question: {input}
""")

# %% [markdown]
# ---
#
# ## 2. 단일 SQL의 한계 - 왜 Decomposition이 필요한가?
#
# Text2SQL에서 복잡한 질문을 하나의 SQL로 처리하면 다음과 같은 문제가 발생합니다:
#
# | 문제 유형 | 예시 | 원인 |
# |-----------|------|------|
# | **다중 비교** | "A 운용사와 B 운용사를 비교해주세요" | 두 조건을 하나의 쿼리로 묶기 어려움 |
# | **순차 의존** | "가장 큰 운용사의 ETF 중 수익률 최고는?" | 1단계 결과가 2단계 조건이 됨 |
# | **다중 집계** | "평균 수익률, 총보수, 순자산을 비교해주세요" | 여러 집계를 동시에 정확히 생성하기 어려움 |
#
# **DIN-SQL 논문**에서는 질문 분해(decomposition)만으로 Text2SQL 정확도가 **+10% 이상** 향상됨을 보였습니다.

# %%
# 복잡한 질문을 단일 SQL로 처리할 때의 한계
complex_questions = [
    "삼성자산운용과 미래에셋자산운용의 ETF 수와 평균 수익률을 비교해주세요",
    "총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?",
    "수익률 상위 5개 ETF와 하위 5개 ETF의 운용사가 겹치는지 알려주세요",
]

print("복잡한 질문에 대한 기본 Chain의 응답:")
print("=" * 60)

for q in complex_questions:
    result = basic_chain.invoke({"question": q})
    print(f"\nQ: {q}")
    print(f"SQL: {result['query']}")
    print(f"Answer: {result['answer']}")
    print("-" * 60)
# Out:
# 복잡한 질문에 대한 기본 Chain의 응답:
# ============================================================
#
# Q: 삼성자산운용과 미래에셋자산운용의 ETF 수와 평균 수익률을 비교해주세요
# SQL: SELECT 운용사, COUNT(*) AS ETF수, AVG(수익률_최근1년) AS 평균수익률 FROM ETFs WHERE 운용사 IN ('삼성자산운용', '미래에셋자산운용') GROUP BY 운용사;
# Answer: 삼성자산운용은 ETF가 202개로 미래에셋자산운용의 200개보다 약간 많으며, 평균 수익률은 6.59%로 미래에셋자산운용의 7.36%보다 낮습니다. 따라서 삼성자산운용은 ETF 수는 더 많지만, 평균 수익률은 미래에셋자산운용에 비해 다소 낮은 편입니다.
# ------------------------------------------------------------
#
# Q: 총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?
# SQL: SELECT 운용사, 종목명, 총보수, 수익률_최근1년 FROM ETFs WHERE 총보수 = (SELECT MIN(총보수) FROM ETFs) ORDER BY 수익률_최근1년 DESC LIMIT 3;
# Answer: 총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는 다음과 같습니다:
#
# 1. 운용사: 한국투자신탁운용
#    종목명: ACE 러시아MSCI(합성)
#    총보수: 0.0
#    수익률(최근 1년): -9.07%
#
# 해당 조건에 맞는 ETF가 1개만 존재하며, 수익률 상위 3개 중 1개만 결과에 나타났습니다.
# ------------------------------------------------------------
#
# Q: 수익률 상위 5개 ETF와 하위 5개 ETF의 운용사가 겹치는지 알려주세요
# SQL: WITH RankedETFs AS (
#   SELECT 운용사, 수익률_최근1년,
#          RANK() OVER (ORDER BY 수익률_최근1년 DESC) AS rank_desc,
#          RANK() OVER (ORDER BY 수익률_최근1년 ASC) AS rank_asc
#   FROM ETFs
# )
# SELECT CASE WHEN EXISTS (
#     SELECT 1 FROM (
#       SELECT 운용사 FROM RankedETFs WHERE rank_desc <= 5
#       INTERSECT
#       SELECT 운용사 FROM RankedETFs WHERE rank_asc <= 5
#     )
# ) THEN 'Yes' ELSE 'No' END AS 운용사_겹침 여부;
# Answer: 제공해주신 SQL 쿼리에서 `AS 운용사_겹침 여부` 부분 때문에 SQLite에서 구문 오류가 발생한 것으로 보입니다. SQLite에서는 별칭에 공백이나 특수문자를 사용할 때 따옴표로 감싸줘야 합니다.
#
# 예를 들어, 아래와 같이 별칭에 공백 대신 언더스코어(_)를 사용하거나, 공백이 필요한 경우 큰따옴표(") 또는 대괄호([])로 감싸야 합니다.
#
# ```sql
# WITH RankedETFs AS (
#   SELECT 운용사, 수익률_최근1년,
#          RANK() OVER (ORDER BY 수익률_최근1년 DESC) AS rank_desc,
#          RANK() OVER (ORDER BY 수익률_최근1년 ASC) AS rank_asc
#   FROM ETFs
# )
# SELECT CASE WHEN EXISTS (
#     SELECT 1 FROM (
#       SELECT 운용사 FROM RankedETFs WHERE rank_desc <= 5
#       INTERSECT
#       SELECT 운용사 FROM RankedETFs WHERE rank_asc <= 5
#     )
# ) THEN 'Yes' ELSE 'No' END AS 운용사_겹침_여부;
# ```
#
# 또는
#
# ```sql
# ...
# ) THEN 'Yes' ELSE 'No' END AS "운용사 겹침 여부";
# ```
#
# 만약 쿼리를 수정한 후 실행 결과가 나오면, 그 결과를 바탕으로 답변을 드릴 수 있습니다.
#
# ---
#
# 현재 오류로 인해 결과를 얻지 못하였으므로, 질문에 대한 직접적인 답변은 어려우나, 쿼리가 정상 실행되면:
#
# - 'Yes' 라면 수익률 상위 5개 ETF와 하위 5개 ETF의 운용사가 겹칩니다.
# - 'No' 라면 겹치지 않습니다.
#
# 따라서 쿼리를 수정하여 다시 실행해 보시고 결과를 알려주시면, 그에 맞게 한국어로 답변을 드리겠습니다.
# ------------------------------------------------------------

# %% [markdown]
# 위 결과에서 볼 수 있듯이, 단일 SQL로는:
# - **비교 질문**: 두 운용사의 데이터를 하나의 쿼리로 정확히 비교하기 어려움
# - **순차 질문**: "가장 낮은 운용사를 먼저 찾고 → 그 운용사의 ETF를 조회" 2단계가 필요
# - **교차 질문**: 상위/하위 결과를 각각 조회한 뒤 비교해야 함
#
# 이런 문제를 **Query Decomposition**으로 해결합니다.

# %% [markdown]
# ---
#
# ## 3. Query Decomposition 구현
#
# ### 핵심 아이디어
# 복잡한 질문을 **독립적인 서브 질문**으로 분해하고, 각각의 SQL을 생성·실행한 뒤, 결과를 종합합니다.
#
# ```
# 원래 질문: "A 운용사와 B 운용사의 ETF 수와 평균 수익률을 비교해주세요"
#
#   ┌─ 서브 질문 1: "A 운용사의 ETF 수와 평균 수익률은?"
#   ├─ 서브 질문 2: "B 운용사의 ETF 수와 평균 수익률은?"
#   └─ 종합: 두 결과를 비교하여 최종 답변 생성
# ```
#
# ### 분해 전략 (Aggregation Strategy)
# | 전략 | 설명 | 예시 |
# |------|------|------|
# | `compare` | 서로 다른 조건의 결과를 비교 | "A와 B를 비교해주세요" |
# | `aggregate` | 여러 집계를 종합 | "평균, 최대, 최소를 모두 알려주세요" |
# | `sequential` | 1단계 결과 → 2단계 조건 | "가장 큰 X의 Y는?" |

# %% [markdown]
# ### 3.1 질문 분해기 (Question Decomposer)
#
# LLM이 질문의 복잡도를 판단하고, 필요시 서브 질문으로 분해합니다.
# `Pydantic` 모델로 구조화된 출력을 강제하여 안정적인 분해 결과를 얻습니다.

# %%
from pydantic import BaseModel, Field
from typing import Literal

class DecomposedQuestions(BaseModel):
    """질문 분해 결과"""
    is_complex: bool = Field(description="분해가 필요한 복잡한 질문인지 여부")
    reasoning: str = Field(description="복잡도 판단 근거")
    sub_questions: List[str] = Field(
        description="분해된 서브 질문들 (단순 질문이면 원래 질문 1개)"
    )
    aggregation_strategy: Literal["compare", "aggregate", "sequential"] = Field(
        description=(
            "결과 종합 방법: "
            "compare(서로 다른 조건의 결과 비교), "
            "aggregate(여러 집계 종합), "
            "sequential(이전 결과를 다음 조건으로 사용)"
        )
    )

decompose_prompt = ChatPromptTemplate.from_messages([
    ("system", """당신은 데이터베이스 질문 분석 전문가입니다.
사용자의 질문이 단일 SQL로 처리할 수 있는지 판단하고,
복잡한 경우 서브 질문으로 분해하세요.

## 분해 기준
- 2개 이상의 **독립적인 조건/그룹**의 결과를 비교하는 경우 → 분해 (compare)
- 여러 **서로 다른 집계**(평균, 개수, 최대 등)를 동시에 구하는 경우 → 분해 (aggregate)
- 한 쿼리의 **결과를 다른 쿼리의 조건**으로 사용하는 경우 → 분해 (sequential)
- 단순 조회, 단일 집계, 단일 필터 → 분해 불필요

## 분해 불필요 예시
- "ETF 총 개수는?" → 단순 COUNT
- "KB자산운용의 ETF 중 수익률 상위 5개는?" → 단일 WHERE + ORDER BY
- "운용사별 평균 총보수는?" → 단일 GROUP BY

## 분해 필요 예시
- "A와 B를 비교해주세요" → compare: [A의 정보?, B의 정보?]
- "가장 X인 Y의 Z는?" → sequential: [가장 X인 Y는?, Y의 Z는?]

## 주의사항
- 서브 질문은 **각각 독립적으로 SQL 쿼리가 가능**하도록 구체적으로 작성
- sequential의 경우 후속 질문에 선행 질문의 결과를 참조하는 표현 포함

데이터베이스 스키마:
{schema}"""),
    ("user", "질문: {question}")
])

decomposer = llm.with_structured_output(DecomposedQuestions)

# %%
# 단순 질문 테스트
simple_q = "ETF 총 개수는?"
result = decomposer.invoke(
    decompose_prompt.invoke({"schema": db.get_table_info(), "question": simple_q})
)
print(f"Q: {simple_q}")
print(f"  복잡: {result.is_complex}")
print(f"  근거: {result.reasoning}")
print(f"  서브 질문: {result.sub_questions}")
print(f"  종합 방법: {result.aggregation_strategy}")
# Out:
# Q: ETF 총 개수는?
#   복잡: False
#   근거: 질문은 ETF의 총 개수를 묻고 있으며, 단일 COUNT 집계로 처리 가능하다.
#   서브 질문: ['ETF 총 개수는?']
#   종합 방법: aggregate

# %%
# 복잡한 질문 분해 테스트
test_questions = [
    "삼성자산운용과 미래에셋자산운용의 ETF 수와 평균 수익률을 비교해주세요",
    "총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?",
    "수익률 상위 5개 ETF와 하위 5개 ETF의 운용사가 겹치는지 알려주세요",
    "운용사별 ETF 개수는?",  # 단순 - 분해 불필요
]

for q in test_questions:
    result = decomposer.invoke(
        decompose_prompt.invoke({"schema": db.get_table_info(), "question": q})
    )
    print(f"\nQ: {q}")
    print(f"  복잡: {result.is_complex} | 전략: {result.aggregation_strategy}")
    print(f"  근거: {result.reasoning}")
    if result.is_complex:
        for i, sq in enumerate(result.sub_questions, 1):
            print(f"  서브 {i}: {sq}")
    print("-" * 50)
# Out:
# Q: 삼성자산운용과 미래에셋자산운용의 ETF 수와 평균 수익률을 비교해주세요
#   복잡: True | 전략: compare
#   근거: 질문은 두 운용사(삼성자산운용, 미래에셋자산운용)의 ETF 수와 평균 수익률을 각각 구한 뒤, 그 결과를 비교하는 형태입니다. 따라서 두 그룹의 독립적인 집계 결과를 비교하는 것으로 복수 집계 결과를 비교하는 'compare' 유형으로 분해가 필요합니다.
#   서브 1: 삼성자산운용이 운용하는 ETF의 수는?
#   서브 2: 삼성자산운용이 운용하는 ETF의 평균 수익률은?
#   서브 3: 미래에셋자산운용이 운용하는 ETF의 수는?
#   서브 4: 미래에셋자산운용이 운용하는 ETF의 평균 수익률은?
# --------------------------------------------------
#
# Q: 총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?
#   복잡: True | 전략: sequential
#   근거: 질문의 '총보수가 가장 낮은 운용사'를 먼저 찾고, 그 운용사의 ETF 중 수익률 상위 3개를 구해야 하므로 sequential 분해가 필요하다.
#   서브 1: 총보수가 가장 낮은 운용사는 누구인가?
#   서브 2: 총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는 무엇인가?
# --------------------------------------------------
#
# Q: 수익률 상위 5개 ETF와 하위 5개 ETF의 운용사가 겹치는지 알려주세요
#   복잡: True | 전략: compare
#   근거: 질문은 상위 5개와 하위 5개 수익률 ETF 각각의 운용사를 구하고, 두 집단의 운용사 겹침 여부를 비교하는 과정을 포함하여 최소 두 개의 독립적인 쿼리가 필요합니다. 따라서 단일 SQL로 처리하기 어렵고 서브 질문으로 분해해야 합니다.
#   서브 1: 수익률 상위 5개 ETF의 운용사 목록은?
#   서브 2: 수익률 하위 5개 ETF의 운용사 목록은?
#   서브 3: 수익률 상위 5개와 하위 5개 ETF의 운용사 목록이 겹치는가?
# --------------------------------------------------
#
# Q: 운용사별 ETF 개수는?
#   복잡: False | 전략: aggregate
#   근거: 질문은 단일 조건('운용사'별 그룹화)으로 각 그룹의 ETF 개수를 구하는 단순 GROUP BY 집계 문의로, 복잡한 분해가 필요하지 않습니다.
# --------------------------------------------------

# %% [markdown]
# ### 3.2 LangGraph 분해-실행-종합 파이프라인
#
# Decomposition 파이프라인의 3단계:
# 1. **decompose**: 질문을 서브 질문으로 분해
# 2. **execute_subs**: 각 서브 질문에 대해 Few-Shot SQL 생성 → 실행
# 3. **synthesize**: 서브 결과를 종합하여 최종 답변 생성

# %%
class DecompState(TypedDict):
    question: str
    is_complex: bool
    sub_questions: list
    aggregation_strategy: str
    sub_results: list
    query: str       # 단순 질문용
    result: str      # 단순 질문용
    answer: str

def decompose_question(state: DecompState):
    """질문 복잡도 분석 및 분해"""
    result = decomposer.invoke(
        decompose_prompt.invoke({
            "schema": db.get_table_info(),
            "question": state["question"]
        })
    )
    
    if not result.is_complex:
        print(f"  단순 질문 -> 분해 없이 처리")
        return {
            "is_complex": False,
            "sub_questions": [state["question"]],
            "aggregation_strategy": "sequential"
        }
    
    print(f"  복잡한 질문 -> {len(result.sub_questions)}개 서브 질문으로 분해")
    print(f"  전략: {result.aggregation_strategy}")
    for i, sq in enumerate(result.sub_questions, 1):
        print(f"     {i}. {sq}")
    
    return {
        "is_complex": True,
        "sub_questions": result.sub_questions,
        "aggregation_strategy": result.aggregation_strategy
    }

def execute_sub_questions(state: DecompState):
    """각 서브 질문에 대해 Few-Shot SQL 생성 및 실행"""
    sub_results = []
    tool = QuerySQLDatabaseTool(db=db)
    
    for i, sq in enumerate(state["sub_questions"], 1):
        print(f"\n  서브 질문 {i}: {sq}")
        
        # Few-Shot 예시 검색
        similar_docs = example_retriever.invoke(sq)
        formatted = format_examples(similar_docs)
        
        # SQL 생성 (Few-Shot + Entity Matching)
        prompt = fewshot_prompt_template.invoke({
            "dialect": db.dialect,
            "top_k": 10,
            "table_info": db.get_table_info(),
            "entity_info": entity_retriever_tool.invoke(sq),
            "examples": formatted,
            "input": sq,
        })
        structured_llm = llm.with_structured_output(QueryOutput)
        query_result = structured_llm.invoke(prompt)
        sql = query_result["query"]
        
        # SQL 실행
        try:
            result = tool.invoke(sql)
        except Exception as e:
            result = f"오류: {str(e)}"
        
        sub_results.append({
            "question": sq,
            "sql": sql,
            "result": result
        })
        print(f"     SQL: {sql[:100]}")
        print(f"     결과: {str(result)[:120]}")
    
    return {"sub_results": sub_results}

def synthesize_results(state: DecompState):
    """서브 결과를 종합하여 최종 답변 생성"""
    sub_info = ""
    for i, sr in enumerate(state["sub_results"], 1):
        sub_info += (
            f"\n--- 서브 질문 {i} ---\n"
            f"질문: {sr['question']}\n"
            f"SQL: {sr['sql']}\n"
            f"결과: {sr['result']}\n"
        )
    
    strategy = state.get("aggregation_strategy", "sequential")
    
    synthesis_prompt = f"""사용자의 원래 질문에 대해 완전한 답변을 생성하세요.

원래 질문: {state['question']}
종합 전략: {strategy}

각 서브 질문의 실행 결과:
{sub_info}

## 종합 가이드라인
- compare: 두 결과를 나란히 비교하여 차이점을 명확히 설명
- aggregate: 여러 집계 결과를 통합하여 종합적인 분석 제공
- sequential: 순차적 결과를 연결하여 논리적 흐름으로 답변

한국어로 명확하고 구체적으로 답변하세요."""
    
    response = llm.invoke(synthesis_prompt)
    return {"answer": response.content}

# %%
# Decomposition 그래프
decomp_graph = StateGraph(DecompState)

decomp_graph.add_node("decompose", decompose_question)
decomp_graph.add_node("execute_subs", execute_sub_questions)
decomp_graph.add_node("synthesize", synthesize_results)

decomp_graph.add_edge(START, "decompose")
decomp_graph.add_edge("decompose", "execute_subs")
decomp_graph.add_edge("execute_subs", "synthesize")
decomp_graph.add_edge("synthesize", END)

decomp_chain = decomp_graph.compile()

display(Image(decomp_chain.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### 3.3 Decomposition 파이프라인 테스트

# %%
# 테스트 1: 비교(compare) 질문
print("=" * 60)
print("테스트 1: 비교(compare) 질문")
print("=" * 60)
result = decomp_chain.invoke({
    "question": "삼성자산운용과 미래에셋자산운용의 ETF 수와 평균 수익률을 비교해주세요"
})
print(f"\n최종 답변:\n{result['answer']}")
# Out:
# ============================================================
# 테스트 1: 비교(compare) 질문
# ============================================================
#   복잡한 질문 -> 4개 서브 질문으로 분해
#   전략: compare
#      1. 삼성자산운용이 운용하는 ETF의 총 개수는?
#      2. 삼성자산운용이 운용하는 ETF의 평균 수익률은?
#      3. 미래에셋자산운용이 운용하는 ETF의 총 개수는?
#      4. 미래에셋자산운용이 운용하는 ETF의 평균 수익률은?
#
#   서브 질문 1: 삼성자산운용이 운용하는 ETF의 총 개수는?
#      SQL: SELECT COUNT(*) FROM ETFs WHERE 운용사 = '삼성자산운용'
#      결과: [(202,)]
#
#   서브 질문 2: 삼성자산운용이 운용하는 ETF의 평균 수익률은?
#      SQL: SELECT AVG(수익률_최근1년) AS 평균_수익률 FROM ETFs WHERE 운용사 = '삼성자산운용'
#      결과: [(6.585792079207921,)]
#
#   서브 질문 3: 미래에셋자산운용이 운용하는 ETF의 총 개수는?
#      SQL: SELECT COUNT(*) FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#      결과: [(200,)]
#
#   서브 질문 4: 미래에셋자산운용이 운용하는 ETF의 평균 수익률은?
#      SQL: SELECT AVG(수익률_최근1년) AS avg_return FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#      결과: [(7.3618,)]
#
# 최종 답변:
# 삼성자산운용과 미래에셋자산운용이 운용하는 ETF의 수와 평균 수익률을 비교하면 다음과 같습니다.
#
# 1. **운용 중인 ETF 수**
# - 삼성자산운용: 202개
# - 미래에셋자산운용: 200개
#
# 두 자산운용사의 ETF 운용 개수는 거의 비슷하며, 삼성자산운용이 약간 더 많은 ETF를 운용하고 있습니다.
#
# 2. **최근 1년 평균 수익률**
# - 삼성자산운용: 약 6.59%
# - 미래에셋자산운용: 약 7.36%
#
# 평균 수익률 측면에서는 미래에셋자산운용이 삼성자산운용보다 약 0.77%p 높아 상대적으로 높은 성과를 보이고 있습니다.
#
# ### 종합평가
# 삼성자산운용은 약간 더 많은 ETF를 운용하고 있지만, 미래에셋자산운용의 ETF가 최근 1년 수익률에서 더 우수한 결과를 보여주고 있습니다. 투자자는 ETF 수량뿐만 아니라 수익률 성과도 함께 고려하여 투자 판단을 하는 것이 바람직합니다.

# %%
# 테스트 2: 순차(sequential) 질문
print("=" * 60)
print("테스트 2: 순차(sequential) 질문")
print("=" * 60)
result = decomp_chain.invoke({
    "question": "총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?"
})
print(f"\n최종 답변:\n{result['answer']}")
# Out:
# ============================================================
# 테스트 2: 순차(sequential) 질문
# ============================================================
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: sequential
#      1. 총보수가 가장 낮은 운용사는?
#      2. 그 운용사의 ETF 중에서 수익률 상위 3개는?
#
#   서브 질문 1: 총보수가 가장 낮은 운용사는?
#      SQL: SELECT 운용사, MIN(총보수) as 최소_총보수 FROM ETFs GROUP BY 운용사 ORDER BY 최소_총보수 ASC LIMIT 10
#      결과: [('한국투자신탁운용', 0.0), ('미래에셋자산운용', 0.008), ('삼성자산운용', 0.008), ('케이비자산운용', 0.008), ('키움투자자산운용', 0.009), ('한화자산운용', 0.009),
#
#   서브 질문 2: 그 운용사의 ETF 중에서 수익률 상위 3개는?
#      SQL: SELECT 종목명, 수익률_최근1년 FROM ETFs WHERE 운용사 = '그' ORDER BY 수익률_최근1년 DESC LIMIT 3
#      결과:
#
# 최종 답변:
# 총보수가 가장 낮은 운용사를 확인한 결과, 한국투자신탁운용이 총보수 0.0으로 가장 낮았습니다. 따라서, 한국투자신탁운용의 ETF 중 수익률 상위 3개 종목을 조회하려 하였으나, 해당 데이터 조회 결과가 제공되지 않아 구체적인 종목명과 수익률 정보를 확인할 수 없었습니다.
#
# 요약하면,
#
# 1. 총보수가 가장 낮은 운용사: 한국투자신탁운용 (총보수 0.0)
# 2. 해당 운용사의 수익률 상위 3개 ETF: 데이터 미제공으로 확인 불가
#
# 추가 데이터가 확보되는 대로 이 운용사의 ETF 수익률 상위 3개 종목을 안내해 드리겠습니다.
# 만약 다른 낮은 총보수 운용사(예: 미래에셋자산운용, 삼성자산운용 등)의 ETF 수익률 정보를 원하시면 말씀해 주세요.

# %%
# 테스트 3: 단순 질문 (분해 불필요)
print("=" * 60)
print("테스트 3: 단순 질문 (분해 불필요)")
print("=" * 60)
result = decomp_chain.invoke({"question": "ETF 총 개수는?"})
print(f"\n최종 답변:\n{result['answer']}")
# Out:
# ============================================================
# 테스트 3: 단순 질문 (분해 불필요)
# ============================================================
#   단순 질문 -> 분해 없이 처리
#
#   서브 질문 1: ETF 총 개수는?
#      SQL: SELECT COUNT(*) FROM ETFs
#      결과: [(930,)]
#
# 최종 답변:
# 현재 데이터베이스 기준으로 전체 ETF의 총 개수는 930개입니다. 이는 ETF 목록 테이블에서 집계된 결과로, 시장에서 거래되고 있는 다양한 ETF의 총합을 의미합니다. 따라서, 사용자가 궁금한 ETF 총 개수는 930개임을 알려드립니다.

# %% [markdown]
# ---
#
# ## 4. Decomposition vs 단일 SQL 비교
#
# 분해 기법의 효과를 확인하기 위해 동일한 복잡 질문에 대해
# 기본 Chain(단일 SQL)과 Decomposition Chain의 결과를 비교합니다.

# %%
# 비교 테스트
comparison_questions = [
    "삼성자산운용과 미래에셋자산운용의 ETF 수와 평균 수익률을 비교해주세요",
    "총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?",
    "순자산총액 상위 10개 ETF의 운용사별 분포와 각 운용사의 평균 총보수는?",
]

for q in comparison_questions:
    print("=" * 70)
    print(f"Q: {q}")
    print("=" * 70)
    
    # 기본 Chain (단일 SQL)
    print("\n[기본 Chain - 단일 SQL]")
    basic_result = basic_chain.invoke({"question": q})
    print(f"  SQL: {basic_result['query'][:120]}")
    print(f"  답변: {basic_result['answer']}")
    
    # Decomposition Chain
    print("\n[Decomposition Chain]")
    decomp_result = decomp_chain.invoke({"question": q})
    print(f"  서브 질문 수: {len(decomp_result.get('sub_results', []))}")
    for sr in decomp_result.get("sub_results", []):
        print(f"    - {sr['question'][:60]}")
        print(f"      SQL: {sr['sql'][:100]}")
    print(f"  답변: {decomp_result['answer']}")
    print()
# Out:
# ======================================================================
# Q: 삼성자산운용과 미래에셋자산운용의 ETF 수와 평균 수익률을 비교해주세요
# ======================================================================
#
# [기본 Chain - 단일 SQL]
#   SQL: SELECT 운용사, COUNT(*) AS ETF_수, AVG(수익률_최근1년) AS 평균_수익률 FROM ETFs WHERE 운용사 IN ('삼성자산운용', '미래에셋자산운용') GROUP BY 운용사 ORDER
#   답변: 삼성자산운용은 ETF가 총 202개로 미래에셋자산운용의 200개보다 약간 많으며, 평균 수익률은 6.59%로 미래에셋자산운용의 7.36%보다 다소 낮습니다.
#
# [Decomposition Chain]
#   복잡한 질문 -> 4개 서브 질문으로 분해
#   전략: compare
#      1. 삼성자산운용이 운용하는 ETF의 수는?
#      2. 삼성자산운용이 운용하는 ETF의 평균 수익률은?
#      3. 미래에셋자산운용이 운용하는 ETF의 수는?
#      4. 미래에셋자산운용이 운용하는 ETF의 평균 수익률은?
#
#   서브 질문 1: 삼성자산운용이 운용하는 ETF의 수는?
#      SQL: SELECT COUNT(*) FROM ETFs WHERE 운용사 = '삼성자산운용'
#      결과: [(202,)]
#
#   서브 질문 2: 삼성자산운용이 운용하는 ETF의 평균 수익률은?
#      SQL: SELECT AVG(수익률_최근1년) AS 평균_수익률 FROM ETFs WHERE 운용사 = '삼성자산운용'
#      결과: [(6.585792079207921,)]
#
#   서브 질문 3: 미래에셋자산운용이 운용하는 ETF의 수는?
#      SQL: SELECT COUNT(*) FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#      결과: [(200,)]
#
#   서브 질문 4: 미래에셋자산운용이 운용하는 ETF의 평균 수익률은?
#      SQL: SELECT AVG(수익률_최근1년) AS 평균_수익률 FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#      결과: [(7.3618,)]
#   서브 질문 수: 4
#     - 삼성자산운용이 운용하는 ETF의 수는?
#       SQL: SELECT COUNT(*) FROM ETFs WHERE 운용사 = '삼성자산운용'
#     - 삼성자산운용이 운용하는 ETF의 평균 수익률은?
#       SQL: SELECT AVG(수익률_최근1년) AS 평균_수익률 FROM ETFs WHERE 운용사 = '삼성자산운용'
#     - 미래에셋자산운용이 운용하는 ETF의 수는?
#       SQL: SELECT COUNT(*) FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#     - 미래에셋자산운용이 운용하는 ETF의 평균 수익률은?
#       SQL: SELECT AVG(수익률_최근1년) AS 평균_수익률 FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#   답변: 삼성자산운용과 미래에셋자산운용의 ETF 운용 현황과 수익률을 비교하면 다음과 같습니다.
#
# 1. **ETF 운용 수**
# - 삼성자산운용은 총 202개의 ETF를 운용하고 있습니다.
# - 미래에셋자산운용은 총 200개의 ETF를 운용 중입니다.
# 즉, 삼성자산운용이 미래에셋자산운용보다 약간 더 많은 ETF를 운용하고 있습니다.
#
# 2. **ETF 평균 수익률 (최근 1년 기준)**
# - 삼성자산운용의 ETF 평균 수익률은 약 6.59%입니다.
# - 미래에셋자산운용의 ETF 평균 수익률은 약 7.36%로, 삼성자산운용보다 약 0.77%p 더 높은 성과를 기록하고 있습니다.
#
# **종합적으로** 보면, 삼성자산운용은 운용 ETF 수가 조금 더 많지만, 미래에셋자산운용은 평균 수익률에서 다소 우위를 점하고 있습니다. 투자 측면에서는 수익률의 차이가 크지 않은 편이나, 미래에셋자산운용이 최근 1년간 더 높은 수익률을 내며 상대적으로 더 좋은 퍼포먼스를 보여주고 있다고 평가할 수 있습니다.
#
# ======================================================================
# Q: 총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?
# ======================================================================
#
# [기본 Chain - 단일 SQL]
#   SQL: SELECT 운용사, 종목명, 수익률_최근1년, 총보수 FROM ETFs WHERE 총보수 = (SELECT MIN(총보수) FROM ETFs) ORDER BY 수익률_최근1년 DESC LIMIT 3;
#   답변: 총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개 중 현재 데이터에는 '한국투자신탁운용'의 'ACE 러시아MSCI(합성)' 한 종목만 있으며, 수익률은 -9.07%입니다.
#
# [Decomposition Chain]
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: sequential
#      1. 총보수가 가장 낮은 운용사는 어디인가?
#      2. 총보수가 가장 낮은 운용사의 ETF 중에서 수익률 상위 3개는 무엇인가?
#
#   서브 질문 1: 총보수가 가장 낮은 운용사는 어디인가?
#      SQL: SELECT 운용사, MIN(총보수) AS 최저_총보수 FROM ETFs GROUP BY 운용사 ORDER BY 최저_총보수 ASC LIMIT 10
#      결과: [('한국투자신탁운용', 0.0), ('미래에셋자산운용', 0.008), ('삼성자산운용', 0.008), ('케이비자산운용', 0.008), ('키움투자자산운용', 0.009), ('한화자산운용', 0.009),
#
#   서브 질문 2: 총보수가 가장 낮은 운용사의 ETF 중에서 수익률 상위 3개는 무엇인가?
#      SQL: SELECT 운용사, 종목명, 수익률_최근1년, 총보수 FROM ETFs WHERE 총보수 = (SELECT MIN(총보수) FROM ETFs) ORDER BY 수익률_최근1년 D
#      결과: [('한국투자신탁운용', 'ACE 러시아MSCI(합성)', -9.07, 0.0)]
#   서브 질문 수: 2
#     - 총보수가 가장 낮은 운용사는 어디인가?
#       SQL: SELECT 운용사, MIN(총보수) AS 최저_총보수 FROM ETFs GROUP BY 운용사 ORDER BY 최저_총보수 ASC LIMIT 10
#     - 총보수가 가장 낮은 운용사의 ETF 중에서 수익률 상위 3개는 무엇인가?
#       SQL: SELECT 운용사, 종목명, 수익률_최근1년, 총보수 FROM ETFs WHERE 총보수 = (SELECT MIN(총보수) FROM ETFs) ORDER BY 수익률_최근1년 D
#   답변: 총보수가 가장 낮은 운용사를 찾기 위해 ETF 데이터베이스를 분석한 결과, 총보수가 0.0%로 가장 낮은 운용사는 **한국투자신탁운용**임을 확인했습니다. 그 외 미래에셋자산운용, 삼성자산운용 등도 총보수가 0.008% 내외로 낮게 나타났습니다.
#
# 하지만 한국투자신탁운용의 총보수 0.0%인 ETF 중 수익률을 조사한 결과, 상위 3개의 ETF 중 실제로는 수익률이 높은 상품이 없어, 수익률 상위 3개로 분류할만한 종목이 한 개(‘ACE 러시아MSCI(합성)’, 수익률 -9.07%)에 불과했습니다. 즉, 총보수가 가장 낮은 운용사의 ETF들은 최근 1년 기준으로 수익률이 좋지 않은 편이었습니다.
#
# 요약하면:
#
# - **총보수가 가장 낮은 운용사:** 한국투자신탁운용 (총보수 0.0%)
# - **해당 운용사의 총보수 최저 ETF 중 수익률 상위 3개:** 수익률 상위 종목이 1개(ACE 러시아MSCI(합성))에 불과하며, 수익률은 -9.07%로 마이너스임
# - 따라서 총보수가 가장 낮은 운용사 ETF들은 수익률 상위 3개를 꼽기 어려운 상황이며, 수익률이 전반적으로 낮은 편임
#
# 결론적으로, 총보수가 가장 낮은 한국투자신탁운용의 ETF 중 수익률 상위 3개는 존재하지 않거나 모두 수익률이 부진한 편임을 참고하시기 바랍니다.
#
# ======================================================================
# Q: 순자산총액 상위 10개 ETF의 운용사별 분포와 각 운용사의 평균 총보수는?
# ======================================================================
#
# [기본 Chain - 단일 SQL]
#   SQL: SELECT 운용사, COUNT(*) AS ETF_개수, AVG(총보수) AS 평균_총보수
# FROM (SELECT 운용사, 총보수
#       FROM ETFs
#       ORDER BY 순자산총액 DESC
#
#   답변: 순자산총액 상위 10개 ETF 중에서 운용사별 분포는 삼성자산운용과 미래에셋자산운용이 각각 5개씩 차지하고 있습니다. 각 운용사의 평균 총보수는 삼성자산운용이 약 0.0558%, 미래에셋자산운용이 약 0.138%입니다.
#
# [Decomposition Chain]
#   복잡한 질문 -> 3개 서브 질문으로 분해
#   전략: aggregate
#      1. 순자산총액 상위 10개 ETF를 선택한다.
#      2. 선택된 상위 10개 ETF 중 운용사별 ETF 개수를 구한다.
#      3. 선택된 상위 10개 ETF 중 각 운용사의 평균 총보수를 구한다.
#
#   서브 질문 1: 순자산총액 상위 10개 ETF를 선택한다.
#      SQL: SELECT 종목명, 순자산총액 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 10
#      결과: [('KODEX CD금리액티브(합성)', 9591343573385.0), ('TIGER CD금리투자KIS(합성)', 6871517745155.0), ('TIGER 미국S&P500', 6433623514411.0),
#
#   서브 질문 2: 선택된 상위 10개 ETF 중 운용사별 ETF 개수를 구한다.
#      SQL: SELECT 운용사, COUNT(*) AS cnt FROM (SELECT 운용사 FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 10) GROUP BY 운용사
#      결과: [('한국투자신탁운용', 2), ('타임폴리오자산운용', 2), ('미래에셋자산운용', 2), ('한화자산운용', 1), ('엔에이치아문디자산운용', 1), ('에셋플러스자산운용', 1), ('삼성자산운용', 1)]
#
#   서브 질문 3: 선택된 상위 10개 ETF 중 각 운용사의 평균 총보수를 구한다.
#      SQL: SELECT 운용사, AVG(총보수) AS 평균_총보수 FROM (SELECT * FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 10) GROUP BY 운용
#      결과: [('에셋플러스자산운용', 0.99), ('타임폴리오자산운용', 0.8), ('엔에이치아문디자산운용', 0.6), ('미래에셋자산운용', 0.52), ('한화자산운용', 0.5), ('삼성자산운용', 0.5), ('
#   서브 질문 수: 3
#     - 순자산총액 상위 10개 ETF를 선택한다.
#       SQL: SELECT 종목명, 순자산총액 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 10
#     - 선택된 상위 10개 ETF 중 운용사별 ETF 개수를 구한다.
#       SQL: SELECT 운용사, COUNT(*) AS cnt FROM (SELECT 운용사 FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 10) GROUP BY 운용사
#     - 선택된 상위 10개 ETF 중 각 운용사의 평균 총보수를 구한다.
#       SQL: SELECT 운용사, AVG(총보수) AS 평균_총보수 FROM (SELECT * FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 10) GROUP BY 운용
#   답변: 순자산총액 기준 상위 10개 ETF의 운용사별 분포와 각 운용사의 평균 총보수를 종합하면 다음과 같습니다.
#
# 1. **순자산총액 상위 10개 ETF 현황**
#    - 상위 10개 ETF는 주로 ‘KODEX’와 ‘TIGER’ 브랜드로 구성되어 있으며,
#    - 대표 ETF로는 ‘KODEX CD금리액티브(합성)’, ‘TIGER CD금리투자KIS(합성)’, ‘TIGER 미국S&P500’ 등이 포함되어 있습니다.
#    - 이들의 순자산총액은 약 3천억 원대부터 9조 5천억 원대까지 다양합니다.
#
# 2. **운용사별 분포**
#    - 10개 ETF는 총 7개 운용사에서 운용하고 있으며,
#    - 운용사별로는 아래와 같은 ETF 보유 개수를 보여줍니다.
#      - 한국투자신탁운용: 2개
#      - 타임폴리오자산운용: 2개
#      - 미래에셋자산운용: 2개
#      - 한화자산운용: 1개
#      - 엔에이치아문디자산운용: 1개
#      - 에셋플러스자산운용: 1개
#      - 삼성자산운용: 1개
#
# 3. **운용사별 평균 총보수**
#    - 각 운용사의 평균 총보수(%)는 다음과 같이 나타납니다.
#      - 에셋플러스자산운용: 0.99%
#      - 타임폴리오자산운용: 0.80%
#      - 엔에이치아문디자산운용: 0.60%
#      - 미래에셋자산운용: 0.52%
#      - 한화자산운용: 0.50%
#      - 삼성자산운용: 0.50%
#      - 한국투자신탁운용: 0.45%
#
# 4. **종합 분석**
#    - 상위 10개 ETF는 주로 3개 운용사(한국투자신탁운용, 타임폴리오자산운용, 미래에셋자산운용)가 다수 ETF를 보유하며 시장 영향력이 큰 편입니다.
#    - 총보수 관점에서는 에셋플러스자산운용의 평균 총보수가 가장 높아 약 1% 수준이며, 한국투자신탁운용이 가장 낮은 0.45% 수준으로 나타났습니다.
#    - 보유 ETF 수가 많은 운용사가 반드시 총보수가 낮은 것이 아니며, 운용 전략 및 ETF 유형에 따라 수수료 구조가 다양하게 형성되어 있음을 알 수 있습니다.
#
# 따라서, 순자산총액 상위 10개 ETF는 여러 운용사에 분포되어 있으나 3개사가 다수를 차지하며, 운용사별 평균 총보수는 0.45%에서 0.99% 사이로 다양하게 나타납니다. 투자 시 운용사별 보수 수준과 ETF 특성을 함께 고려하는 것이 바람직합니다.

# %% [markdown]
# ---
#
# ## 5. 통합 파이프라인 - 조건부 라우팅
#
# 실제 서비스에서는 모든 질문을 분해할 필요가 없습니다.
# **질문 복잡도에 따라 자동으로 경로를 선택**하는 통합 파이프라인을 구축합니다.
#
# ```
# 사용자 질문
#     │
#     ▼
# [복잡도 분석]
#     │
#     ├── 단순 → [Few-Shot SQL 생성] → [실행] → [답변 생성]
#     │
#     └── 복잡 → [서브 질문 분해] → [각각 실행] → [결과 종합]
# ```

# %%
def route_by_complexity(state: DecompState) -> str:
    """복잡도에 따라 처리 경로 선택"""
    if state.get("is_complex", False):
        return "execute_subs"
    return "simple_query"

def simple_query(state: DecompState):
    """단순 질문: Few-Shot SQL 생성 + 실행"""
    similar_docs = example_retriever.invoke(state["question"])
    formatted = format_examples(similar_docs)
    
    prompt = fewshot_prompt_template.invoke({
        "dialect": db.dialect,
        "top_k": 10,
        "table_info": db.get_table_info(),
        "entity_info": entity_retriever_tool.invoke(state["question"]),
        "examples": formatted,
        "input": state["question"],
        
    })
    structured_llm = llm.with_structured_output(QueryOutput)
    query_result = structured_llm.invoke(prompt)
    
    tool = QuerySQLDatabaseTool(db=db)
    try:
        result = tool.invoke(query_result["query"])
    except Exception as e:
        result = f"오류: {str(e)}"
    
    return {"query": query_result["query"], "result": result}

def generate_simple_answer(state: DecompState):
    """단순 질문 답변 생성"""
    prompt = (
        "Given the following user question, corresponding SQL query, "
        "and SQL result, answer the user question.\n\n"
        f'Question: {state["question"]}\n'
        f'SQL Query: {state["query"]}\n'
        f'SQL Result: {state["result"]}'
    )
    response = llm.invoke(prompt)
    return {"answer": response.content}

# %%
# 통합 그래프
integrated_graph = StateGraph(DecompState)

integrated_graph.add_node("decompose", decompose_question)
integrated_graph.add_node("simple_query", simple_query)
integrated_graph.add_node("execute_subs", execute_sub_questions)
integrated_graph.add_node("simple_answer", generate_simple_answer)
integrated_graph.add_node("synthesize", synthesize_results)

# 엣지 연결
integrated_graph.add_edge(START, "decompose")
integrated_graph.add_conditional_edges(
    "decompose", 
    route_by_complexity,
      {
        "execute_subs": "execute_subs",
        "simple_query": "simple_query"
    } )
integrated_graph.add_edge("simple_query", "simple_answer")
integrated_graph.add_edge("execute_subs", "synthesize")
integrated_graph.add_edge("simple_answer", END)
integrated_graph.add_edge("synthesize", END)

integrated_chain = integrated_graph.compile()

display(Image(integrated_chain.get_graph().draw_mermaid_png()))

# %%
# 통합 파이프라인 테스트
test_cases = [
    ("단순", "총보수가 0.1% 이하인 ETF 목록을 보여주세요"),
    ("비교", "삼성자산운용과 미래에셋자산운용의 평균 총보수와 ETF 수를 비교해주세요"),
    ("순차", "순자산총액 상위 10개 ETF의 운용사별 분포와 각 운용사의 평균 총보수는?"),
]

for label, q in test_cases:
    print("=" * 60)
    print(f"[{label}] {q}")
    print("=" * 60)
    result = integrated_chain.invoke({"question": q})
    print(f"\n답변:\n{result['answer']}")
    print()
# Out:
# ============================================================
# [단순] 총보수가 0.1% 이하인 ETF 목록을 보여주세요
# ============================================================
#   단순 질문 -> 분해 없이 처리
#
# 답변:
# 총보수가 0.1% 이하인 ETF 목록은 다음과 같습니다:
#
# 1. ACE 러시아MSCI(합성) - 총보수 0.0%
# 2. KODEX 코리아밸류업 - 총보수 0.008%
# 3. RISE 코리아밸류업 - 총보수 0.008%
# 4. TIGER 코리아밸류업 - 총보수 0.008%
# 5. KODEX 미국S&P500(H) - 총보수 0.009%
# 6. KODEX 미국S&P500TR - 총보수 0.009%
# 7. KODEX 미국나스닥100(H) - 총보수 0.009%
# 8. KODEX 미국나스닥100TR - 총보수 0.009%
# 9. KODEX 미국배당다우존스 - 총보수 0.009%
# 10. KOSEF 코리아밸류업 - 총보수 0.009%
#
# ============================================================
# [비교] 삼성자산운용과 미래에셋자산운용의 평균 총보수와 ETF 수를 비교해주세요
# ============================================================
#   복잡한 질문 -> 4개 서브 질문으로 분해
#   전략: compare
#      1. 삼성자산운용의 평균 총보수는 얼마인가?
#      2. 삼성자산운용이 운용하는 ETF 수는 몇 개인가?
#      3. 미래에셋자산운용의 평균 총보수는 얼마인가?
#      4. 미래에셋자산운용이 운용하는 ETF 수는 몇 개인가?
#
#   서브 질문 1: 삼성자산운용의 평균 총보수는 얼마인가?
#      SQL: SELECT AVG(총보수) AS avg_fee FROM ETFs WHERE 운용사 = '삼성자산운용'
#      결과: [(0.2771138613861386,)]
#
#   서브 질문 2: 삼성자산운용이 운용하는 ETF 수는 몇 개인가?
#      SQL: SELECT COUNT(*) AS count FROM ETFs WHERE 운용사 = '삼성자산운용'
#      결과: [(202,)]
#
#   서브 질문 3: 미래에셋자산운용의 평균 총보수는 얼마인가?
#      SQL: SELECT AVG(총보수) AS avg_total_fee FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#      결과: [(0.343105,)]
#
#   서브 질문 4: 미래에셋자산운용이 운용하는 ETF 수는 몇 개인가?
#      SQL: SELECT COUNT(*) FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#      결과: [(200,)]
#
# 답변:
# 삼성자산운용과 미래에셋자산운용의 ETF 운용 현황을 비교하면 다음과 같습니다.
#
# 1. **평균 총보수(운용보수) 비교**
# - 삼성자산운용의 평균 총보수는 약 0.2771%입니다.
# - 미래에셋자산운용의 평균 총보수는 약 0.3431%로, 삼성자산운용보다 다소 높은 편입니다.
#
# 2. **ETF 운용 수 비교**
# - 삼성자산운용은 총 202개의 ETF를 운용하고 있습니다.
# - 미래에셋자산운용은 200개의 ETF를 운용 중으로, 삼성자산운용보다 2개 적습니다.
#
# 종합하면, 삼성자산운용은 미래에셋자산운용에 비해 평균 총보수가 낮으면서도 약간 더 많은 ETF를 운용하고 있는 것으로 나타납니다. 이는 삼성자산운용이 투자자에게 비교적 저렴한 비용으로 다양한 ETF를 제공하고 있음을 시사합니다.
#
# ============================================================
# [순차] 순자산총액 상위 10개 ETF의 운용사별 분포와 각 운용사의 평균 총보수는?
# ============================================================
#   복잡한 질문 -> 3개 서브 질문으로 분해
#   전략: sequential
#      1. 순자산총액 상위 10개 ETF는 어떤 종목인가?
#      2. 그 상위 10개 ETF의 운용사별 분포는 어떻게 되는가?
#      3. 그 상위 10개 ETF의 각 운용사별 평균 총보수는 얼마인가?
#
#   서브 질문 1: 순자산총액 상위 10개 ETF는 어떤 종목인가?
#      SQL: SELECT 종목명, 순자산총액 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 10
#      결과: [('KODEX CD금리액티브(합성)', 9591343573385.0), ('TIGER CD금리투자KIS(합성)', 6871517745155.0), ('TIGER 미국S&P500', 6433623514411.0),
#
#   서브 질문 2: 그 상위 10개 ETF의 운용사별 분포는 어떻게 되는가?
#      SQL: SELECT 운용사, COUNT(*) AS num_etfs FROM (SELECT 운용사 FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 10) GROUP B
#      결과: [('한국투자신탁운용', 2), ('타임폴리오자산운용', 2), ('미래에셋자산운용', 2), ('한화자산운용', 1), ('엔에이치아문디자산운용', 1), ('에셋플러스자산운용', 1), ('삼성자산운용', 1)]
#
#   서브 질문 3: 그 상위 10개 ETF의 각 운용사별 평균 총보수는 얼마인가?
#      SQL: WITH Top10 AS (SELECT * FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 10) SELECT 운용사, AVG(총보수) AS 평균_총보수 FR
#      결과: [('에셋플러스자산운용', 0.99), ('타임폴리오자산운용', 0.8), ('엔에이치아문디자산운용', 0.6), ('미래에셋자산운용', 0.52), ('한화자산운용', 0.5), ('삼성자산운용', 0.5), ('
#
# 답변:
# 순자산총액 기준으로 상위 10개 ETF는 다음과 같습니다:
#
# 1. KODEX CD금리액티브(합성) – 약 9.59조 원
# 2. TIGER CD금리투자KIS(합성) – 약 6.87조 원
# 3. TIGER 미국S&P500 – 약 6.43조 원
# 4. KODEX 200 – 약 5.60조 원
# 5. TIGER 미국나스닥100 – 약 4.49조 원
# 6. KODEX KOFR금리액티브(합성) – 약 4.33조 원
# 7. KODEX 머니마켓액티브 – 약 4.00조 원
# 8. TIGER KOFR금리액티브(합성) – 약 3.48조 원
# 9. TIGER 미국테크TOP10 INDXX – 약 3.14조 원
# 10. KODEX 미국S&P500TR – 약 3.05조 원
#
# 이들 상위 10개 ETF의 운용사별 분포는 다음과 같습니다:
#
# - 한국투자신탁운용: 2개
# - 타임폴리오자산운용: 2개
# - 미래에셋자산운용: 2개
# - 한화자산운용: 1개
# - 엔에이치아문디자산운용: 1개
# - 에셋플러스자산운용: 1개
# - 삼성자산운용: 1개
#
# 즉, ‘한국투자신탁운용’, ‘타임폴리오자산운용’, ‘미래에셋자산운용’ 세 운용사가 각각 2개의 ETF를 보유하고 있으며, 나머지 네 운용사는 각각 1개의 ETF를 보유하고 있습니다. 이로써 대체로 특정 운용사에 편중되지 않고 비교적 다양한 운용사가 상위권 ETF를 운용하고 있음을 알 수 있습니다.
#
# 각 운용사별 상위 10개 ETF의 평균 총보수는 다음과 같습니다:
#
# - 에셋플러스자산운용: 0.99%
# - 타임폴리오자산운용: 0.80%
# - 엔에이치아문디자산운용: 0.60%
# - 미래에셋자산운용: 0.52%
# - 한화자산운용: 0.50%
# - 삼성자산운용: 0.50%
# - 한국투자신탁운용: 약 0.45%
#
# 운용사별로 총보수 차이가 존재하는데, 에셋플러스자산운용이 가장 높은 평균 총보수(0.99%)를 부과하고 있으며, 한국투자신탁운용이 가장 낮은 평균 총보수(약 0.45%)를 부과하는 것으로 나타났습니다. 이는 각 ETF의 운용 전략, 운용 규모, 비용 구조 등에 따라 총보수 수준이 상이함을 반영합니다.
#
# 요약하면, 순자산총액 상위 10개 ETF는 7개의 운용사에 의해 분포되어 있으며, 이중 상위 3개 운용사가 6개의 ETF를 운용하고 있습니다. 이들 ETF의 평균 총보수는 운용사별로 약 0.45%부터 0.99%까지 폭넓게 차이가 납니다. 투자 시에는 운용사의 총보수 수준과 ETF의 투자 목적 및 운용 전략을 함께 고려하는 것이 바람직합니다.

# %%
# 통합 파이프라인 테스트
test_cases = [
    ("단순", "총보수가 0.1% 이하인 ETF 목록을 보여주세요"),
    ("비교", "삼성자산운용과 미래에셋자산운용의 평균 총보수와 ETF 수를 비교해주세요"),
    ("순차", "순자산총액 상위 10개 ETF의 운용사별 분포와 각 운용사의 평균 총보수는?"),
]

for label, q in test_cases:
    print("=" * 60)
    print(f"[{label}] {q}")
    print("=" * 60)
    result = integrated_chain.invoke({"question": q})
    print(f"\n답변:\n{result['answer']}")
    print()
# Out:
# ============================================================
# [단순] 총보수가 0.1% 이하인 ETF 목록을 보여주세요
# ============================================================
#   단순 질문 -> 분해 없이 처리
#
# 답변:
# 총보수가 0.1% 이하인 ETF 목록은 다음과 같습니다:
#
# 1. ACE 러시아MSCI(합성) - 0.0%
# 2. KODEX 코리아밸류업 - 0.008%
# 3. RISE 코리아밸류업 - 0.008%
# 4. TIGER 코리아밸류업 - 0.008%
# 5. KODEX 미국S&P500(H) - 0.009%
# 6. KODEX 미국S&P500TR - 0.009%
# 7. KODEX 미국나스닥100(H) - 0.009%
# 8. KODEX 미국나스닥100TR - 0.009%
# 9. KODEX 미국배당다우존스 - 0.009%
# 10. KOSEF 코리아밸류업 - 0.009%
#
# ============================================================
# [비교] 삼성자산운용과 미래에셋자산운용의 평균 총보수와 ETF 수를 비교해주세요
# ============================================================
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: compare
#      1. 삼성자산운용의 평균 총보수와 ETF 수는?
#      2. 미래에셋자산운용의 평균 총보수와 ETF 수는?
#
#   서브 질문 1: 삼성자산운용의 평균 총보수와 ETF 수는?
#      SQL: SELECT 운용사, COUNT(*) AS etf_count, AVG(총보수) AS avg_fee FROM ETFs WHERE 운용사 = '삼성자산운용' GROUP BY 운용사
#      결과: [('삼성자산운용', 202, 0.2771138613861386)]
#
#   서브 질문 2: 미래에셋자산운용의 평균 총보수와 ETF 수는?
#      SQL: SELECT AVG(총보수) AS avg_fee, COUNT(*) AS etf_count FROM ETFs WHERE 운용사 = '미래에셋자산운용'
#      결과: [(0.343105, 200)]
#
# 답변:
# 삼성자산운용과 미래에셋자산운용의 평균 총보수와 ETF 수를 비교하면 다음과 같습니다.
#
# 1. **ETF 수**
# - 삼성자산운용: 202개
# - 미래에셋자산운용: 200개
# 두 운용사 모두 약 200개의 ETF를 운용하고 있어 ETF 수는 거의 비슷합니다.
#
# 2. **평균 총보수**
# - 삼성자산운용: 약 0.2771%
# - 미래에셋자산운용: 약 0.3431%
# 평균 총보수는 삼성자산운용이 약 0.2771%로 미래에셋자산운용(약 0.3431%)보다 낮아, 삼성자산운용의 ETF가 상대적으로 운용보수가 더 저렴한 편입니다.
#
# **종합적으로 보면,** 삼성자산운용과 미래에셋자산운용은 ETF 운용 수량은 거의 비슷하지만, 삼성자산운용이 평균 운용보수 측면에서 더 경쟁력 있는 수준임을 알 수 있습니다. 이는 비용 효율성을 중요시하는 투자자 입장에서 삼성자산운용의 ETF가 다소 유리할 수 있음을 시사합니다.
#
# ============================================================
# [순차] 순자산총액 상위 10개 ETF의 운용사별 분포와 각 운용사의 평균 총보수는?
# ============================================================
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: aggregate
#      1. 순자산총액 상위 10개 ETF를 추출하고, 그 ETF들의 운용사별 분포(운용사별 ETF 개수)를 구하세요.
#      2. 상위 10개 ETF에 속하는 각 운용사의 평균 총보수를 구하세요.
#
#   서브 질문 1: 순자산총액 상위 10개 ETF를 추출하고, 그 ETF들의 운용사별 분포(운용사별 ETF 개수)를 구하세요.
#      SQL: WITH Top10_ETFs AS (SELECT 종목코드, 운용사 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 10) SELECT 운용사, COUNT(*) as
#      결과: [('미래에셋자산운용', 5), ('삼성자산운용', 5)]
#
#   서브 질문 2: 상위 10개 ETF에 속하는 각 운용사의 평균 총보수를 구하세요.
#      SQL: SELECT 운용사, AVG(총보수) AS 평균_총보수 FROM (SELECT * FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 10) GROUP BY 운용
#      결과: [('한국투자신탁운용', 0.44999999999999996), ('삼성자산운용', 0.5), ('한화자산운용', 0.5), ('미래에셋자산운용', 0.52), ('엔에이치아문디자산운용', 0.6), ('타임폴리오자
#
# 답변:
# 순자산총액 기준으로 상위 10개 ETF를 살펴본 결과, 이들 ETF는 **미래에셋자산운용과 삼성자산운용** 두 운용사에 각각 5개씩 균등하게 분포하고 있습니다. 즉, 상위 10개의 ETF 중 절반씩 양사가 운용하고 있습니다.
#
# 한편, 각 운용사별 **상위 10개 ETF의 평균 총보수**를 살펴보면, 질문에서 요구한 ‘상위 10개 ETF에 속하는 각 운용사’의 평균 총보수 데이터와, 순자산총액 상위 10개 ETF의 운용사 분포 간에는 차이가 있습니다.
# - 상위 10개 ETF 전체(순자산총액 기준) 운용사의 평균 총보수는 따로 제공되지 않았으나, 유사 비교로 최근 1년 수익률 기준 상위 10개 ETF의 평균 총보수를 보면 다음과 같습니다.
#   - 삼성자산운용: 약 0.50%
#   - 미래에셋자산운용: 약 0.52%
#   (참고로 이 외 운용사들은 순자산총액 상위 10개에는 포함되지 않았습니다.)
#
# 따라서, **순자산총액 상위 10개 ETF를 기준으로 할 때 두 운용사의 평균 총보수는 대체로 0.5% 내외**로 유사한 수준일 것으로 추정됩니다.
#
# ### 요약
# - **운용사별 분포**: 미래에셋자산운용 5개, 삼성자산운용 5개 (상위 10개 ETF 기준)
# - **평균 총보수**: 두 운용사 모두 약 0.5% 내외로 비슷한 수준(수익률 기준 상위 10개 ETF 데이터 참고)
# - 두 운용사는 한국 ETF 시장에서 순자산 기준 최상위권 ETF를 균등하게 보유하고 있으며, 수수료 수준도 비슷하게 유지하고 있습니다.
#
# 결론적으로, 순자산총액 상위 ETF 시장은 미래에셋과 삼성자산운용이 양분하고 있으며, 두 운용사의 ETF 관리 비용(총보수)도 경쟁력 있는 수준으로 나타납니다.

# %%
# [예시 정답] Sequential Decomposition 개선
#
# 핵심: sequential 전략일 때 이전 서브 질문의 결과를
# 다음 서브 질문의 컨텍스트로 전달하여 정확도 향상

def execute_sub_questions_sequential(state: DecompState):
    """
    서브 질문 실행 (sequential 전략 개선 버전)
    - compare/aggregate: 기존과 동일하게 독립 실행
    - sequential: 이전 서브 질문의 결과를 다음 서브 질문에 반영
    """
    sub_results = []
    tool = QuerySQLDatabaseTool(db=db)
    strategy = state.get("aggregation_strategy", "sequential")
    
    for i, sq in enumerate(state["sub_questions"]):
        # sequential 전략이고 첫 번째 서브 질문이 아닌 경우
        # → 이전 결과를 현재 질문에 컨텍스트로 추가
        if strategy == "sequential" and i > 0:
            prev = sub_results[i - 1]
            sq_with_context = (
                f"{sq}\n"
                f"(참고: 이전 단계 질문 '{prev['question']}'의 결과 = {prev['result']})"
            )
            print(f"\n  서브 질문 {i+1} (이전 결과 반영): {sq}")
        else:
            sq_with_context = sq
            print(f"\n  서브 질문 {i+1}: {sq}")
        
        # Few-Shot 예시 검색 (원래 질문으로 검색하여 관련 예시 확보)
        similar_docs = example_retriever.invoke(sq)
        formatted = format_examples(similar_docs)
        
        # SQL 생성 (컨텍스트가 포함된 질문 사용)
        prompt = fewshot_prompt_template.invoke({
            "dialect": db.dialect,
            "top_k": 10,
            "table_info": db.get_table_info(),
            "entity_info": entity_retriever_tool.invoke(sq),
            "examples": formatted,
            "input": sq_with_context,  # 이전 결과가 포함된 질문
        })
        structured_llm = llm.with_structured_output(QueryOutput)
        query_result = structured_llm.invoke(prompt)
        sql = query_result["query"]
        
        # SQL 실행
        try:
            result = tool.invoke(sql)
        except Exception as e:
            result = f"오류: {str(e)}"
        
        sub_results.append({
            "question": sq,
            "sql": sql,
            "result": result
        })
        print(f"     SQL: {sql[:100]}")
        print(f"     결과: {str(result)[:120]}")
    
    return {"sub_results": sub_results}


# 개선된 Decomposition 그래프 구성
improved_graph = StateGraph(DecompState)

improved_graph.add_node("decompose", decompose_question)
improved_graph.add_node("execute_subs", execute_sub_questions_sequential)  # 개선된 버전
improved_graph.add_node("synthesize", synthesize_results)

improved_graph.add_edge(START, "decompose")
improved_graph.add_edge("decompose", "execute_subs")
improved_graph.add_edge("execute_subs", "synthesize")
improved_graph.add_edge("synthesize", END)

improved_chain = improved_graph.compile()

display(Image(improved_chain.get_graph().draw_mermaid_png()))

# %%
# 개선 전후 비교: Sequential 질문 테스트
sequential_questions = [
    "총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?",
    "순자산총액이 가장 큰 ETF의 운용사에서 다른 ETF는 뭐가 있나요?",
    "수익률이 가장 높은 분류체계에서 총보수가 가장 낮은 ETF는?",
]

for q in sequential_questions:
    print("=" * 70)
    print(f"Q: {q}")
    print("=" * 70)
    
    # 기존 방식 (독립 실행)
    print("\n[기존 - 독립 실행]")
    result_old = decomp_chain.invoke({"question": q})
    for sr in result_old.get("sub_results", []):
        print(f"  서브: {sr['question'][:50]}")
        print(f"  SQL: {sr['sql'][:80]}")
    print(f"  답변: {result_old['answer']}...")
    
    # 개선 방식 (이전 결과 반영)
    print("\n[개선 - 이전 결과 반영]")
    result_new = improved_chain.invoke({"question": q})
    for sr in result_new.get("sub_results", []):
        print(f"  서브: {sr['question'][:50]}")
        print(f"  SQL: {sr['sql'][:80]}")
    print(f"  답변: {result_new['answer']}...")
    print()
# Out:
# ======================================================================
# Q: 총보수가 가장 낮은 운용사의 ETF 중 수익률 상위 3개는?
# ======================================================================
#
# [기존 - 독립 실행]
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: sequential
#      1. 총보수가 가장 낮은 운용사는?
#      2. 그 운용사의 ETF 중 수익률 상위 3개는?
#
#   서브 질문 1: 총보수가 가장 낮은 운용사는?
#      SQL: SELECT 운용사, MIN(총보수) AS 최소_총보수 FROM ETFs GROUP BY 운용사 ORDER BY 최소_총보수 ASC LIMIT 10
#      결과: [('한국투자신탁운용', 0.0), ('미래에셋자산운용', 0.008), ('삼성자산운용', 0.008), ('케이비자산운용', 0.008), ('키움투자자산운용', 0.009), ('한화자산운용', 0.009),
#
#   서브 질문 2: 그 운용사의 ETF 중 수익률 상위 3개는?
#      SQL: SELECT 운용사, 종목명, 수익률_최근1년 FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 3
#      결과: [('한국투자신탁운용', 'ACE 미국빅테크TOP7 Plus레버리지(합성)', 207.87), ('한화자산운용', 'PLUS 미국테크TOP10레버리지(합성)', 179.94), ('미래에셋자산운용', 'TIGER 미
#   서브: 총보수가 가장 낮은 운용사는?
#   SQL: SELECT 운용사, MIN(총보수) AS 최소_총보수 FROM ETFs GROUP BY 운용사 ORDER BY 최소_총보수 ASC LIMIT
#   서브: 그 운용사의 ETF 중 수익률 상위 3개는?
#   SQL: SELECT 운용사, 종목명, 수익률_최근1년 FROM ETFs ORDER BY 수익률_최근1년 DESC LIMIT 3
#   답변: 총보수가 가장 낮은 운용사들을 확인한 결과, 한국투자신탁운용이 0.0으로 가장 낮았고, 미래에셋자산운용과 삼성자산운용, 케이비자산운용 등이 0.008로 그 뒤를 이었습니다. 이 중에서 총보수가 가장 낮은 '한국투자신탁운용'의 ETF 중 수익률 상위 3개를 확인해 보면, 가장 높은 수익률을 기록한 종목은 'ACE 미국빅테크TOP7 Plus레버리지(합성)'로 최근 1년간 207.87%의 수익률을 기록했습니다.
#
# 종합하면, 총보수가 가장 낮은 운용사 중에서 특히 한국투자신탁운용의 ETF들이 높은 수익률을 보여주고 있으며, 대표적으로 'ACE 미국빅테크TOP7 Plus레버리지(합성)' ETF가 수익률 상위권에 위치해 있습니다. 따라서 총보수가 매우 낮은 한국투자신탁운용의 ETF를 중심으로 투자할 경우, 높은 수익률을 기대할 수 있다고 할 수 있습니다.
#
# 추가로, 미래에셋자산운용과 한화자산운용도 총보수가 상대적으로 낮고 수익률이 뛰어난 ETF를 보유하고 있으나, 가장 낮은 총보수를 기록한 한국투자신탁운용이 수익률 상위 3개 ETF 중 다수를 포함하고 있음을 알 수 있습니다....
#
# [개선 - 이전 결과 반영]
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: sequential
#      1. 총보수가 가장 낮은 운용사는 어디인가?
#      2. 그 운용사의 ETF 중 수익률 상위 3개는 무엇인가?
#
#   서브 질문 1: 총보수가 가장 낮은 운용사는 어디인가?
#      SQL: SELECT 운용사, MIN(총보수) AS 최저총보수 FROM ETFs GROUP BY 운용사 ORDER BY 최저총보수 ASC LIMIT 10
#      결과: [('한국투자신탁운용', 0.0), ('미래에셋자산운용', 0.008), ('삼성자산운용', 0.008), ('케이비자산운용', 0.008), ('키움투자자산운용', 0.009), ('한화자산운용', 0.009),
#
#   서브 질문 2 (이전 결과 반영): 그 운용사의 ETF 중 수익률 상위 3개는 무엇인가?
#      SQL: SELECT 종목명, 수익률_최근1년 FROM ETFs WHERE 운용사 = '한국투자신탁운용' ORDER BY 수익률_최근1년 DESC LIMIT 3
#      결과: [('ACE 미국빅테크TOP7 Plus레버리지(합성)', 207.87), ('ACE 미국빅테크TOP7 Plus', 85.06), ('ACE 테슬라밸류체인액티브', 75.57)]
#   서브: 총보수가 가장 낮은 운용사는 어디인가?
#   SQL: SELECT 운용사, MIN(총보수) AS 최저총보수 FROM ETFs GROUP BY 운용사 ORDER BY 최저총보수 ASC LIMIT 10
#   서브: 그 운용사의 ETF 중 수익률 상위 3개는 무엇인가?
#   SQL: SELECT 종목명, 수익률_최근1년 FROM ETFs WHERE 운용사 = '한국투자신탁운용' ORDER BY 수익률_최근1년 DESC LIM
#   답변: 총보수가 가장 낮은 운용사는 '한국투자신탁운용'으로, 총보수가 0.0인 상품도 존재합니다. 이 운용사의 ETF 중 최근 1년 수익률 상위 3개 종목은 다음과 같습니다:
#
# 1. ACE 미국빅테크TOP7 Plus레버리지(합성) — 수익률 207.87%
# 2. ACE 미국빅테크TOP7 Plus — 수익률 85.06%
# 3. ACE 테슬라밸류체인액티브 — 수익률 75.57%
#
# 따라서, 총보수가 가장 낮은 운용사의 ETF 중 수익률이 높은 상위 3개 종목은 위와 같이 ACE 브랜드의 미국 빅테크 관련 레버리지 및 액티브 펀드가 차지하고 있음을 알 수 있습니다....
#
# ======================================================================
# Q: 순자산총액이 가장 큰 ETF의 운용사에서 다른 ETF는 뭐가 있나요?
# ======================================================================
#
# [기존 - 독립 실행]
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: sequential
#      1. 순자산총액이 가장 큰 ETF는 무엇인가?
#      2. 순자산총액이 가장 큰 ETF의 운용사에서 운용하는 다른 ETF들은 무엇인가?
#
#   서브 질문 1: 순자산총액이 가장 큰 ETF는 무엇인가?
#      SQL: SELECT 종목명, 순자산총액 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 1
#      결과: [('KODEX CD금리액티브(합성)', 9591343573385.0)]
#
#   서브 질문 2: 순자산총액이 가장 큰 ETF의 운용사에서 운용하는 다른 ETF들은 무엇인가?
#      SQL: WITH LargestETF AS (SELECT 운용사 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 1) SELECT 종목명, 순자산총액 FROM ETFs WH
#      결과: [('KODEX CD금리액티브(합성)', 9591343573385.0), ('KODEX 200', 5604796801979.0), ('KODEX KOFR금리액티브(합성)', 4331602537465.0), ('KOD
#   서브: 순자산총액이 가장 큰 ETF는 무엇인가?
#   SQL: SELECT 종목명, 순자산총액 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 1
#   서브: 순자산총액이 가장 큰 ETF의 운용사에서 운용하는 다른 ETF들은 무엇인가?
#   SQL: WITH LargestETF AS (SELECT 운용사 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 1) SELECT 종목명
#   답변: 순자산총액이 가장 큰 ETF는 'KODEX CD금리액티브(합성)'이며, 그 운용사는 KODEX입니다. 이 운용사에서 운용하는 주요 다른 ETF들은 다음과 같습니다:
#
# 1. KODEX 200 (순자산총액 약 5.6조 원)
# 2. KODEX KOFR금리액티브(합성) (약 4.3조 원)
# 3. KODEX 머니마켓액티브 (약 4.0조 원)
# 4. KODEX 미국S&P500TR (약 3.0조 원)
# 5. KODEX 종합채권(AA-이상)액티브 (약 2.8조 원)
# 6. KODEX 레버리지 (약 2.3조 원)
# 7. KODEX 200TR (약 2.2조 원)
# 8. KODEX 1년은행양도성예금증서+액티브(합성) (약 1.8조 원)
# 9. KODEX 코스닥150레버리지 (약 1.7조 원)
#
# 즉, 순자산총액 기준으로 가장 큰 ETF를 운용하는 KODEX는 다양한 자산군과 전략에 걸쳐 여러 대형 ETF를 운용하고 있음을 알 수 있습니다. 이들 ETF는 국내 주요 주가지수, 채권, 금리, 그리고 해외 주식시장 지수 등 다양한 시장을 포괄하고 있습니다....
#
# [개선 - 이전 결과 반영]
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: sequential
#      1. 순자산총액이 가장 큰 ETF는 무엇인가?
#      2. 첫번째 질문에서 찾은 ETF의 운용사에 속한 다른 ETF 목록은 무엇인가?
#
#   서브 질문 1: 순자산총액이 가장 큰 ETF는 무엇인가?
#      SQL: SELECT 종목명, 순자산총액 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 1
#      결과: [('KODEX CD금리액티브(합성)', 9591343573385.0)]
#
#   서브 질문 2 (이전 결과 반영): 첫번째 질문에서 찾은 ETF의 운용사에 속한 다른 ETF 목록은 무엇인가?
#      SQL: SELECT 종목명, 순자산총액, 총보수 FROM ETFs WHERE 운용사 = (SELECT 운용사 FROM ETFs WHERE 종목명 = 'KODEX CD금리액티브(합성)')
#      결과: [('KODEX 200', 5604796801979.0, 0.15), ('KODEX KOFR금리액티브(합성)', 4331602537465.0, 0.05), ('KODEX 머니마켓액티브', 4004995260449.0
#   서브: 순자산총액이 가장 큰 ETF는 무엇인가?
#   SQL: SELECT 종목명, 순자산총액 FROM ETFs ORDER BY 순자산총액 DESC LIMIT 1
#   서브: 첫번째 질문에서 찾은 ETF의 운용사에 속한 다른 ETF 목록은 무엇인가?
#   SQL: SELECT 종목명, 순자산총액, 총보수 FROM ETFs WHERE 운용사 = (SELECT 운용사 FROM ETFs WHERE 종목명 = '
#   답변: 순자산총액이 가장 큰 ETF는 'KODEX CD금리액티브(합성)'로, 순자산총액이 약 9.59조 원에 달합니다. 이 ETF는 'KODEX' 운용사에서 관리하고 있습니다.
#
# 해당 운용사의 다른 주요 ETF들도 순자산총액 규모가 상당히 크며, 주요 종목과 순자산총액, 총보수는 다음과 같습니다.
#
# 1. **KODEX 200**
#    - 순자산총액: 약 5.60조 원
#    - 총보수: 0.15%
#
# 2. **KODEX KOFR금리액티브(합성)**
#    - 순자산총액: 약 4.33조 원
#    - 총보수: 0.05%
#
# 3. **KODEX 머니마켓액티브**
#    - 순자산총액: 약 4.00조 원
#    - 총보수: 0.05%
#
# 4. **KODEX 미국S&P500TR**
#    - 순자산총액: 약 3.05조 원
#    - 총보수: 0.009%
#
# 5. **KODEX 종합채권(AA-이상)액티브**
#    - 순자산총액: 약 2.82조 원
#    - 총보수: 0.045%
#
# 6. **KODEX 레버리지**
#    - 순자산총액: 약 2.29조 원
#    - 총보수: 0.6%
#
# 7. **KODEX 200TR**
#    - 순자산총액: 약 2.19조 원
#    - 총보수: 0.05%
#
# 8. **KODEX 1년은행양도성예금증서+액티브(합성)**
#    - 순자산총액: 약 1.81조 원
#    - 총보수: 0.05%
#
# 9. **KODEX 코스닥150레버리지**
#    - 순자산총액: 약 1.72조 원
#    - 총보수: 0.6%
#
# 10. **KODEX 미국나스닥100TR**
#     - 순자산총액: 약 1.70조 원
#     - 총보수: 0.009%
#
# 요약하면, 순자산총액이 가장 큰 ETF인 'KODEX CD금리액티브(합성)'를 운용하는 'KODEX' 운용사는 다양한 자산 유형을 아우르는 여러 규모가 큰 ETF들을 보유하고 있습니다. 이들 ETF는 주식, 채권, 레버리지, 미국 주요 지수 추종 등으로 구성되어 있으며, 보수는 0.009%에서 0.6%까지 다양합니다. 따라서 'KODEX' 운용사는 국내외 시장을 폭넓게 커버하는 다양한 상품 라인업을 갖추고 있어 투자자들의 다양한 수요를 충족시키고 있습니다....
#
# ======================================================================
# Q: 수익률이 가장 높은 분류체계에서 총보수가 가장 낮은 ETF는?
# ======================================================================
#
# [기존 - 독립 실행]
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: sequential
#      1. 수익률이 가장 높은 분류체계는 무엇인가?
#      2. 그 분류체계에서 총보수가 가장 낮은 ETF는 무엇인가?
#
#   서브 질문 1: 수익률이 가장 높은 분류체계는 무엇인가?
#      SQL: SELECT 분류체계, AVG(수익률_최근1년) AS avg_return FROM ETFs GROUP BY 분류체계 ORDER BY avg_return DESC LIMIT 1
#      결과: [('주식-업종섹터-중공업', 54.01)]
#
#   서브 질문 2: 그 분류체계에서 총보수가 가장 낮은 ETF는 무엇인가?
#      SQL: WITH MinFee AS (SELECT 분류체계, MIN(총보수) AS Min총보수 FROM ETFs GROUP BY 분류체계) SELECT e.분류체계, e.종목명, e.총보수
#      결과: [('기타', 'TIGER CD1년금리액티브(합성)', 0.009), ('기타', 'TIGER CD금리플러스액티브(합성)', 0.009), ('부동산', 'TIGER 리츠부동산인프라', 0.08), ('부동산-리츠'
#   서브: 수익률이 가장 높은 분류체계는 무엇인가?
#   SQL: SELECT 분류체계, AVG(수익률_최근1년) AS avg_return FROM ETFs GROUP BY 분류체계 ORDER BY avg_re
#   서브: 그 분류체계에서 총보수가 가장 낮은 ETF는 무엇인가?
#   SQL: WITH MinFee AS (SELECT 분류체계, MIN(총보수) AS Min총보수 FROM ETFs GROUP BY 분류체계) SELECT
#   답변: 사용자의 질문은 "수익률이 가장 높은 분류체계 내에서 총보수가 가장 낮은 ETF는 무엇인가?" 입니다.
#
# 1. 먼저, 수익률이 가장 높은 분류체계를 분석한 결과, **'주식-업종섹터-중공업'**이 최근 1년 수익률 평균 54.01%로 가장 높은 것으로 나타났습니다.
#
# 2. 이어서, 전체 분류체계별로 총보수가 가장 낮은 ETF 목록을 확인한 결과, '주식-업종섹터-중공업' 분류체계에 해당하는 ETF가 목록에 포함되어 있지 않았습니다. 즉, 제공된 총보수 최저 ETF 리스트에는 '주식-업종섹터-중공업' 분류의 ETF 정보가 없었습니다.
#
# 따라서,
#
# - **가장 수익률이 높은 '주식-업종섹터-중공업' 분류체계 내에서 총보수가 가장 낮은 ETF는 별도로 추출되지 않았습니다.**
# - 추가 데이터가 있거나 별도의 쿼리를 실행할 필요가 있으며, 현재 제공된 정보만으로는 정확한 ETF명과 총보수를 알 수 없습니다.
#
# 만약 해당 분류체계 내 총보수가 가장 낮은 ETF를 구체적으로 알고 싶다면, 아래와 같이 조건을 걸어 쿼리를 실행해야 합니다:
#
# ```sql
# SELECT 종목명, 총보수
# FROM ETFs
# WHERE 분류체계 = '주식-업종섹터-중공업'
# ORDER BY 총보수 ASC
# LIMIT 1;
# ```
#
# 결론적으로, 질문에 대한 답변은 "수익률이 가장 높은 분류체계인 '주식-업종섹터-중공업' 내 총보수가 가장 낮은 ETF 정보는 현재 제공된 데이터에 포함되어 있지 않아 확인이 필요하다" 입니다....
#
# [개선 - 이전 결과 반영]
#   복잡한 질문 -> 2개 서브 질문으로 분해
#   전략: sequential
#      1. 수익률이 가장 높은 분류체계는 무엇인가?
#      2. 그 분류체계에서 총보수가 가장 낮은 ETF는 무엇인가?
#
#   서브 질문 1: 수익률이 가장 높은 분류체계는 무엇인가?
#      SQL: SELECT 분류체계, AVG(수익률_최근1년) AS 평균_수익률 FROM ETFs GROUP BY 분류체계 ORDER BY 평균_수익률 DESC LIMIT 10
#      결과: [('주식-업종섹터-중공업', 54.01), ('주식-업종섹터-커뮤니케이션서비스', 31.14), ('주식-업종섹터', 29.843333333333334), ('주식-업종섹터-금융', 27.66875), ('주식-업
#
#   서브 질문 2 (이전 결과 반영): 그 분류체계에서 총보수가 가장 낮은 ETF는 무엇인가?
#      SQL: SELECT 종목명, 총보수 FROM ETFs WHERE 분류체계 = '주식-업종섹터-중공업' ORDER BY 총보수 ASC LIMIT 10
#      결과: [('TIGER 200 중공업', 0.34)]
#   서브: 수익률이 가장 높은 분류체계는 무엇인가?
#   SQL: SELECT 분류체계, AVG(수익률_최근1년) AS 평균_수익률 FROM ETFs GROUP BY 분류체계 ORDER BY 평균_수익률 DES
#   서브: 그 분류체계에서 총보수가 가장 낮은 ETF는 무엇인가?
#   SQL: SELECT 종목명, 총보수 FROM ETFs WHERE 분류체계 = '주식-업종섹터-중공업' ORDER BY 총보수 ASC LIMIT 10
#   답변: 수익률이 가장 높은 분류체계는 ‘주식-업종섹터-중공업’으로, 최근 1년간 평균 수익률은 약 54.01%에 달합니다. 이 중에서 총보수가 가장 낮은 ETF는 ‘TIGER 200 중공업’이며, 총보수는 0.34%입니다.
#
# 따라서, 수익률이 가장 높은 분류체계 내에서 비용 효율이 가장 좋은 ETF는 ‘TIGER 200 중공업’으로 볼 수 있습니다. 높은 수익률과 상대적으로 낮은 총보수를 함께 고려할 때 투자 매력도가 높은 종목이라고 할 수 있습니다....
